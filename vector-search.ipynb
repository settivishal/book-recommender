# %%
from langchain_community.document_loaders import TextLoader
# from langchain_community.embeddings import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
import pandas as pd

books = pd.read_csv('books_cleaned.csv')

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  age_of_books  \
# 0               3.85      247.0          361.0          20.0
# 1               3.83      241.0         5164.0          24.0
# 2               3.93      512.0        29532.0          31.0
# 3               4.15      170.0        33684.0          22.0
# 4               4.09      176.0        37569.0          22.0
# ...              ...        ...            ...           ...
# 5192            2.93      324.0            0.0          21.0
# 5193            3.70      175.0           24.0          22.0
# 5194            3.82      198.0         1568.0          21.0
# 5195            4.51      531.0          104.0          25.0
# 5196            0.00      210.0            0.0          43.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5192  9788172235222 On A Train Journey Home To North...
# 5193  9788173031014 This book tells the tale of a ma...
# 5194  9788179921623 Wisdom to Create a Life of Passi...
# 5195  9788185300535 This collection of the timeless ...
# 5196  9789027712059 Since the three volume edition o...
#
# [5197 rows x 14 columns]

# %%
books["tagged_description"]
# Out:
# 0       9780002005883 A NOVEL THAT READERS and critics...
# 1       9780002261982 A new 'Christie for Christmas' -...
# 2       9780006178736 A memorable, mesmerizing heroine...
# 3       9780006280897 Lewis' work on the nature of lov...
# 4       9780006280934 "In The Problem of Pain, C.S. Le...
#                               ...
# 5192    9788172235222 On A Train Journey Home To North...
# 5193    9788173031014 This book tells the tale of a ma...
# 5194    9788179921623 Wisdom to Create a Life of Passi...
# 5195    9788185300535 This collection of the timeless ...
# 5196    9789027712059 Since the three volume edition o...
# Name: tagged_description, Length: 5197, dtype: object

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   index = False,
                                   header = False)

# %%
raw_documents = TextLoader("tagged_description.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=10, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1170, which is longer than the specified 10
# Created a chunk of size 1216, which is longer than the specified 10
# Created a chunk of size 375, which is longer than the specified 10
# Created a chunk of size 311, which is longer than the specified 10
# Created a chunk of size 483, which is longer than the specified 10
# Created a chunk of size 484, which is longer than the specified 10
# Created a chunk of size 962, which is longer than the specified 10
# Created a chunk of size 188, which is longer than the specified 10
# Created a chunk of size 845, which is longer than the specified 10
# Created a chunk of size 296, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 881, which is longer than the specified 10
# Created a chunk of size 1090, which is longer than the specified 10
# Created a chunk of size 1191, which is longer than the specified 10
# Created a chunk of size 306, which is longer than the specified 10
# Created a chunk of size 270, which is longer than the specified 10
# Created a chunk of size 213, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 515, which is longer than the specified 10
# Created a chunk of size 754, which is longer than the specified 10
# Created a chunk of size 390, which is longer than the specified 10
# Created a chunk of size 265, which is longer than the specified 10
# Created a chunk of size 253, which is longer than the specified 10
# Created a chunk of size 308, which is longer than the specified 10
# Created a chunk of size 730, which is longer than the specified 10
# Created a chunk of size 723, which is longer than the specified 10
# Created a chunk of size 258, which is longer than the specified 10
# Created a chunk of size 475, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 1267, which is longer than the specified 10
# Created a chunk of size 683, which is longer than the specified 10
# Created a chunk of size 243, which is longer than the specified 10
# Created a chunk of size 555, which is longer than the specified 10
# Created a chunk of size 523, which is longer than the specified 10
# Created a chunk of size 282, which is longer than the specified 10
# Created a chunk of size 789, which is longer than the specified 10
# Created a chunk of size 566, which is longer than the specified 10
# Created a chunk of size 525, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 299, which is longer than the specified 10
# Created a chunk of size 535, which is longer than the specified 10
# Created a chunk of size 559, which is longer than the specified 10
# Created a chunk of size 565, which is longer than the specified 10
# Created a chunk of size 385, which is longer than the specified 10
# Created a chunk of size 412, which is longer than the specified 10
# Created a chunk of size 463, which is longer than the specified 10
# Created a chunk of size 597, which is longer than the specified 10
# Created a chunk of size 478, which is longer than the specified 10
# Created a chunk of size 461, which is longer than the specified 10
# Created a chunk of size 259, which is longer than the specified 10
# Created a chunk of size 306, which is longer than the specified 10
# Created a chunk of size 616, which is longer than the specified 10
# Created a chunk of size 421, which is longer than the specified 10
# Created a chunk of size 889, which is longer than the specified 10
# Created a chunk of size 695, which is longer than the specified 10
# Created a chunk of size 304, which is longer than the specified 10
# Created a chunk of size 219, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 2010, which is longer than the specified 10
# Created a chunk of size 175, which is longer than the specified 10
# Created a chunk of size 481, which is longer than the specified 10
# Created a chunk of size 302, which is longer than the specified 10
# Created a chunk of size 522, which is longer than the specified 10
# Created a chunk of size 649, which is longer than the specified 10
# Created a chunk of size 778, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 688, which is longer than the specified 10
# Created a chunk of size 550, which is longer than the specified 10
# Created a chunk of size 1225, which is longer than the specified 10
# Created a chunk of size 408, which is longer than the specified 10
# Created a chunk of size 1186, which is longer than the specified 10
# Created a chunk of size 1216, which is longer than the specified 10
# Created a chunk of size 1193, which is longer than the specified 10
# Created a chunk of size 1059, which is longer than the specified 10
# Created a chunk of size 246, which is longer than the specified 10
# Created a chunk of size 690, which is longer than the specified 10
# Created a chunk of size 878, which is longer than the specified 10
# Created a chunk of size 286, which is longer than the specified 10
# Created a chunk of size 768, which is longer than the specified 10
# Created a chunk of size 389, which is longer than the specified 10
# Created a chunk of size 419, which is longer than the specified 10
# Created a chunk of size 210, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 725, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 163, which is longer than the specified 10
# Created a chunk of size 528, which is longer than the specified 10
# Created a chunk of size 523, which is longer than the specified 10
# Created a chunk of size 214, which is longer than the specified 10
# Created a chunk of size 340, which is longer than the specified 10
# Created a chunk of size 901, which is longer than the specified 10
# Created a chunk of size 1272, which is longer than the specified 10
# Created a chunk of size 560, which is longer than the specified 10
# Created a chunk of size 1637, which is longer than the specified 10
# Created a chunk of size 438, which is longer than the specified 10
# Created a chunk of size 251, which is longer than the specified 10
# Created a chunk of size 779, which is longer than the specified 10
# Created a chunk of size 718, which is longer than the specified 10
# Created a chunk of size 516, which is longer than the specified 10
# Created a chunk of size 960, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 1132, which is longer than the specified 10
# Created a chunk of size 170, which is longer than the specified 10
# Created a chunk of size 1325, which is longer than the specified 10
# Created a chunk of size 853, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 801, which is longer than the specified 10
# Created a chunk of size 1121, which is longer than the specified 10
# Created a chunk of size 838, which is longer than the specified 10
# Created a chunk of size 262, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 734, which is longer than the specified 10
# Created a chunk of size 1195, which is longer than the specified 10
# Created a chunk of size 712, which is longer than the specified 10
# Created a chunk of size 775, which is longer than the specified 10
# Created a chunk of size 280, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 358, which is longer than the specified 10
# Created a chunk of size 768, which is longer than the specified 10
# Created a chunk of size 767, which is longer than the specified 10
# Created a chunk of size 718, which is longer than the specified 10
# Created a chunk of size 2012, which is longer than the specified 10
# Created a chunk of size 308, which is longer than the specified 10
# Created a chunk of size 1288, which is longer than the specified 10
# Created a chunk of size 1231, which is longer than the specified 10
# Created a chunk of size 729, which is longer than the specified 10
# Created a chunk of size 750, which is longer than the specified 10
# Created a chunk of size 447, which is longer than the specified 10
# Created a chunk of size 1242, which is longer than the specified 10
# Created a chunk of size 311, which is longer than the specified 10
# Created a chunk of size 914, which is longer than the specified 10
# Created a chunk of size 306, which is longer than the specified 10
# Created a chunk of size 846, which is longer than the specified 10
# Created a chunk of size 1128, which is longer than the specified 10
# Created a chunk of size 1075, which is longer than the specified 10
# Created a chunk of size 1320, which is longer than the specified 10
# Created a chunk of size 363, which is longer than the specified 10
# Created a chunk of size 2834, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 206, which is longer than the specified 10
# Created a chunk of size 572, which is longer than the specified 10
# Created a chunk of size 208, which is longer than the specified 10
# Created a chunk of size 367, which is longer than the specified 10
# Created a chunk of size 1143, which is longer than the specified 10
# Created a chunk of size 1006, which is longer than the specified 10
# Created a chunk of size 715, which is longer than the specified 10
# Created a chunk of size 712, which is longer than the specified 10
# Created a chunk of size 2510, which is longer than the specified 10
# Created a chunk of size 956, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 351, which is longer than the specified 10
# Created a chunk of size 641, which is longer than the specified 10
# Created a chunk of size 405, which is longer than the specified 10
# Created a chunk of size 525, which is longer than the specified 10
# Created a chunk of size 795, which is longer than the specified 10
# Created a chunk of size 167, which is longer than the specified 10
# Created a chunk of size 391, which is longer than the specified 10
# Created a chunk of size 256, which is longer than the specified 10
# Created a chunk of size 1424, which is longer than the specified 10
# Created a chunk of size 1085, which is longer than the specified 10
# Created a chunk of size 1146, which is longer than the specified 10
# Created a chunk of size 1268, which is longer than the specified 10
# Created a chunk of size 790, which is longer than the specified 10
# Created a chunk of size 297, which is longer than the specified 10
# Created a chunk of size 1088, which is longer than the specified 10
# Created a chunk of size 874, which is longer than the specified 10
# Created a chunk of size 256, which is longer than the specified 10
# Created a chunk of size 876, which is longer than the specified 10
# Created a chunk of size 808, which is longer than the specified 10
# Created a chunk of size 1814, which is longer than the specified 10
# Created a chunk of size 1830, which is longer than the specified 10
# Created a chunk of size 1064, which is longer than the specified 10
# Created a chunk of size 955, which is longer than the specified 10
# Created a chunk of size 1182, which is longer than the specified 10
# Created a chunk of size 283, which is longer than the specified 10
# Created a chunk of size 283, which is longer than the specified 10
# Created a chunk of size 288, which is longer than the specified 10
# Created a chunk of size 1286, which is longer than the specified 10
# Created a chunk of size 1644, which is longer than the specified 10
# Created a chunk of size 759, which is longer than the specified 10
# Created a chunk of size 1932, which is longer than the specified 10
# Created a chunk of size 874, which is longer than the specified 10
# Created a chunk of size 2008, which is longer than the specified 10
# Created a chunk of size 2285, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 1003, which is longer than the specified 10
# Created a chunk of size 579, which is longer than the specified 10
# Created a chunk of size 290, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 1144, which is longer than the specified 10
# Created a chunk of size 559, which is longer than the specified 10
# Created a chunk of size 1143, which is longer than the specified 10
# Created a chunk of size 245, which is longer than the specified 10
# Created a chunk of size 1088, which is longer than the specified 10
# Created a chunk of size 1483, which is longer than the specified 10
# Created a chunk of size 223, which is longer than the specified 10
# Created a chunk of size 1137, which is longer than the specified 10
# Created a chunk of size 724, which is longer than the specified 10
# Created a chunk of size 668, which is longer than the specified 10
# Created a chunk of size 767, which is longer than the specified 10
# Created a chunk of size 608, which is longer than the specified 10
# Created a chunk of size 572, which is longer than the specified 10
# Created a chunk of size 967, which is longer than the specified 10
# Created a chunk of size 859, which is longer than the specified 10
# Created a chunk of size 1034, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 367, which is longer than the specified 10
# Created a chunk of size 497, which is longer than the specified 10
# Created a chunk of size 652, which is longer than the specified 10
# Created a chunk of size 350, which is longer than the specified 10
# Created a chunk of size 735, which is longer than the specified 10
# Created a chunk of size 527, which is longer than the specified 10
# Created a chunk of size 1017, which is longer than the specified 10
# Created a chunk of size 972, which is longer than the specified 10
# Created a chunk of size 206, which is longer than the specified 10
# Created a chunk of size 690, which is longer than the specified 10
# Created a chunk of size 546, which is longer than the specified 10
# Created a chunk of size 244, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 378, which is longer than the specified 10
# Created a chunk of size 933, which is longer than the specified 10
# Created a chunk of size 564, which is longer than the specified 10
# Created a chunk of size 856, which is longer than the specified 10
# Created a chunk of size 717, which is longer than the specified 10
# Created a chunk of size 749, which is longer than the specified 10
# Created a chunk of size 714, which is longer than the specified 10
# Created a chunk of size 326, which is longer than the specified 10
# Created a chunk of size 243, which is longer than the specified 10
# Created a chunk of size 1090, which is longer than the specified 10
# Created a chunk of size 725, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 706, which is longer than the specified 10
# Created a chunk of size 1914, which is longer than the specified 10
# Created a chunk of size 397, which is longer than the specified 10
# Created a chunk of size 487, which is longer than the specified 10
# Created a chunk of size 622, which is longer than the specified 10
# Created a chunk of size 561, which is longer than the specified 10
# Created a chunk of size 558, which is longer than the specified 10
# Created a chunk of size 388, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 427, which is longer than the specified 10
# Created a chunk of size 418, which is longer than the specified 10
# Created a chunk of size 284, which is longer than the specified 10
# Created a chunk of size 168, which is longer than the specified 10
# Created a chunk of size 626, which is longer than the specified 10
# Created a chunk of size 2616, which is longer than the specified 10
# Created a chunk of size 1580, which is longer than the specified 10
# Created a chunk of size 391, which is longer than the specified 10
# Created a chunk of size 996, which is longer than the specified 10
# Created a chunk of size 849, which is longer than the specified 10
# Created a chunk of size 265, which is longer than the specified 10
# Created a chunk of size 338, which is longer than the specified 10
# Created a chunk of size 1530, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 291, which is longer than the specified 10
# Created a chunk of size 2032, which is longer than the specified 10
# Created a chunk of size 398, which is longer than the specified 10
# Created a chunk of size 1619, which is longer than the specified 10
# Created a chunk of size 700, which is longer than the specified 10
# Created a chunk of size 824, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 843, which is longer than the specified 10
# Created a chunk of size 1191, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 510, which is longer than the specified 10
# Created a chunk of size 665, which is longer than the specified 10
# Created a chunk of size 1284, which is longer than the specified 10
# Created a chunk of size 262, which is longer than the specified 10
# Created a chunk of size 244, which is longer than the specified 10
# Created a chunk of size 217, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 1268, which is longer than the specified 10
# Created a chunk of size 1277, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 1058, which is longer than the specified 10
# Created a chunk of size 380, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 224, which is longer than the specified 10
# Created a chunk of size 784, which is longer than the specified 10
# Created a chunk of size 971, which is longer than the specified 10
# Created a chunk of size 615, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 759, which is longer than the specified 10
# Created a chunk of size 291, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 965, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 845, which is longer than the specified 10
# Created a chunk of size 788, which is longer than the specified 10
# Created a chunk of size 650, which is longer than the specified 10
# Created a chunk of size 986, which is longer than the specified 10
# Created a chunk of size 799, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 1163, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 1058, which is longer than the specified 10
# Created a chunk of size 248, which is longer than the specified 10
# Created a chunk of size 877, which is longer than the specified 10
# Created a chunk of size 819, which is longer than the specified 10
# Created a chunk of size 380, which is longer than the specified 10
# Created a chunk of size 757, which is longer than the specified 10
# Created a chunk of size 571, which is longer than the specified 10
# Created a chunk of size 628, which is longer than the specified 10
# Created a chunk of size 868, which is longer than the specified 10
# Created a chunk of size 622, which is longer than the specified 10
# Created a chunk of size 623, which is longer than the specified 10
# Created a chunk of size 1084, which is longer than the specified 10
# Created a chunk of size 2762, which is longer than the specified 10
# Created a chunk of size 1035, which is longer than the specified 10
# Created a chunk of size 760, which is longer than the specified 10
# Created a chunk of size 775, which is longer than the specified 10
# Created a chunk of size 636, which is longer than the specified 10
# Created a chunk of size 1010, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 1066, which is longer than the specified 10
# Created a chunk of size 494, which is longer than the specified 10
# Created a chunk of size 797, which is longer than the specified 10
# Created a chunk of size 701, which is longer than the specified 10
# Created a chunk of size 487, which is longer than the specified 10
# Created a chunk of size 372, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 1226, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 345, which is longer than the specified 10
# Created a chunk of size 659, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 767, which is longer than the specified 10
# Created a chunk of size 555, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 235, which is longer than the specified 10
# Created a chunk of size 592, which is longer than the specified 10
# Created a chunk of size 240, which is longer than the specified 10
# Created a chunk of size 301, which is longer than the specified 10
# Created a chunk of size 728, which is longer than the specified 10
# Created a chunk of size 1807, which is longer than the specified 10
# Created a chunk of size 1017, which is longer than the specified 10
# Created a chunk of size 684, which is longer than the specified 10
# Created a chunk of size 741, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 451, which is longer than the specified 10
# Created a chunk of size 474, which is longer than the specified 10
# Created a chunk of size 924, which is longer than the specified 10
# Created a chunk of size 220, which is longer than the specified 10
# Created a chunk of size 164, which is longer than the specified 10
# Created a chunk of size 969, which is longer than the specified 10
# Created a chunk of size 479, which is longer than the specified 10
# Created a chunk of size 222, which is longer than the specified 10
# Created a chunk of size 647, which is longer than the specified 10
# Created a chunk of size 678, which is longer than the specified 10
# Created a chunk of size 712, which is longer than the specified 10
# Created a chunk of size 801, which is longer than the specified 10
# Created a chunk of size 856, which is longer than the specified 10
# Created a chunk of size 672, which is longer than the specified 10
# Created a chunk of size 213, which is longer than the specified 10
# Created a chunk of size 854, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 762, which is longer than the specified 10
# Created a chunk of size 798, which is longer than the specified 10
# Created a chunk of size 681, which is longer than the specified 10
# Created a chunk of size 929, which is longer than the specified 10
# Created a chunk of size 1268, which is longer than the specified 10
# Created a chunk of size 735, which is longer than the specified 10
# Created a chunk of size 870, which is longer than the specified 10
# Created a chunk of size 933, which is longer than the specified 10
# Created a chunk of size 774, which is longer than the specified 10
# Created a chunk of size 772, which is longer than the specified 10
# Created a chunk of size 337, which is longer than the specified 10
# Created a chunk of size 649, which is longer than the specified 10
# Created a chunk of size 1771, which is longer than the specified 10
# Created a chunk of size 536, which is longer than the specified 10
# Created a chunk of size 826, which is longer than the specified 10
# Created a chunk of size 263, which is longer than the specified 10
# Created a chunk of size 599, which is longer than the specified 10
# Created a chunk of size 488, which is longer than the specified 10
# Created a chunk of size 971, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 556, which is longer than the specified 10
# Created a chunk of size 491, which is longer than the specified 10
# Created a chunk of size 844, which is longer than the specified 10
# Created a chunk of size 878, which is longer than the specified 10
# Created a chunk of size 672, which is longer than the specified 10
# Created a chunk of size 275, which is longer than the specified 10
# Created a chunk of size 709, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 656, which is longer than the specified 10
# Created a chunk of size 1270, which is longer than the specified 10
# Created a chunk of size 260, which is longer than the specified 10
# Created a chunk of size 263, which is longer than the specified 10
# Created a chunk of size 738, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 250, which is longer than the specified 10
# Created a chunk of size 294, which is longer than the specified 10
# Created a chunk of size 1019, which is longer than the specified 10
# Created a chunk of size 366, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 779, which is longer than the specified 10
# Created a chunk of size 684, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 600, which is longer than the specified 10
# Created a chunk of size 665, which is longer than the specified 10
# Created a chunk of size 597, which is longer than the specified 10
# Created a chunk of size 857, which is longer than the specified 10
# Created a chunk of size 597, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 157, which is longer than the specified 10
# Created a chunk of size 539, which is longer than the specified 10
# Created a chunk of size 567, which is longer than the specified 10
# Created a chunk of size 280, which is longer than the specified 10
# Created a chunk of size 707, which is longer than the specified 10
# Created a chunk of size 850, which is longer than the specified 10
# Created a chunk of size 235, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 257, which is longer than the specified 10
# Created a chunk of size 544, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 1179, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 460, which is longer than the specified 10
# Created a chunk of size 906, which is longer than the specified 10
# Created a chunk of size 854, which is longer than the specified 10
# Created a chunk of size 509, which is longer than the specified 10
# Created a chunk of size 220, which is longer than the specified 10
# Created a chunk of size 1717, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 400, which is longer than the specified 10
# Created a chunk of size 847, which is longer than the specified 10
# Created a chunk of size 1681, which is longer than the specified 10
# Created a chunk of size 723, which is longer than the specified 10
# Created a chunk of size 661, which is longer than the specified 10
# Created a chunk of size 605, which is longer than the specified 10
# Created a chunk of size 993, which is longer than the specified 10
# Created a chunk of size 1130, which is longer than the specified 10
# Created a chunk of size 464, which is longer than the specified 10
# Created a chunk of size 2005, which is longer than the specified 10
# Created a chunk of size 218, which is longer than the specified 10
# Created a chunk of size 183, which is longer than the specified 10
# Created a chunk of size 1173, which is longer than the specified 10
# Created a chunk of size 2141, which is longer than the specified 10
# Created a chunk of size 664, which is longer than the specified 10
# Created a chunk of size 1322, which is longer than the specified 10
# Created a chunk of size 528, which is longer than the specified 10
# Created a chunk of size 338, which is longer than the specified 10
# Created a chunk of size 374, which is longer than the specified 10
# Created a chunk of size 1114, which is longer than the specified 10
# Created a chunk of size 666, which is longer than the specified 10
# Created a chunk of size 910, which is longer than the specified 10
# Created a chunk of size 1318, which is longer than the specified 10
# Created a chunk of size 155, which is longer than the specified 10
# Created a chunk of size 693, which is longer than the specified 10
# Created a chunk of size 952, which is longer than the specified 10
# Created a chunk of size 1123, which is longer than the specified 10
# Created a chunk of size 776, which is longer than the specified 10
# Created a chunk of size 615, which is longer than the specified 10
# Created a chunk of size 425, which is longer than the specified 10
# Created a chunk of size 533, which is longer than the specified 10
# Created a chunk of size 1020, which is longer than the specified 10
# Created a chunk of size 727, which is longer than the specified 10
# Created a chunk of size 612, which is longer than the specified 10
# Created a chunk of size 631, which is longer than the specified 10
# Created a chunk of size 465, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 1009, which is longer than the specified 10
# Created a chunk of size 618, which is longer than the specified 10
# Created a chunk of size 884, which is longer than the specified 10
# Created a chunk of size 581, which is longer than the specified 10
# Created a chunk of size 911, which is longer than the specified 10
# Created a chunk of size 1059, which is longer than the specified 10
# Created a chunk of size 632, which is longer than the specified 10
# Created a chunk of size 1255, which is longer than the specified 10
# Created a chunk of size 339, which is longer than the specified 10
# Created a chunk of size 572, which is longer than the specified 10
# Created a chunk of size 1100, which is longer than the specified 10
# Created a chunk of size 909, which is longer than the specified 10
# Created a chunk of size 623, which is longer than the specified 10
# Created a chunk of size 381, which is longer than the specified 10
# Created a chunk of size 290, which is longer than the specified 10
# Created a chunk of size 354, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 411, which is longer than the specified 10
# Created a chunk of size 450, which is longer than the specified 10
# Created a chunk of size 877, which is longer than the specified 10
# Created a chunk of size 340, which is longer than the specified 10
# Created a chunk of size 1145, which is longer than the specified 10
# Created a chunk of size 877, which is longer than the specified 10
# Created a chunk of size 351, which is longer than the specified 10
# Created a chunk of size 622, which is longer than the specified 10
# Created a chunk of size 627, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 553, which is longer than the specified 10
# Created a chunk of size 398, which is longer than the specified 10
# Created a chunk of size 387, which is longer than the specified 10
# Created a chunk of size 843, which is longer than the specified 10
# Created a chunk of size 483, which is longer than the specified 10
# Created a chunk of size 716, which is longer than the specified 10
# Created a chunk of size 923, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 351, which is longer than the specified 10
# Created a chunk of size 583, which is longer than the specified 10
# Created a chunk of size 746, which is longer than the specified 10
# Created a chunk of size 556, which is longer than the specified 10
# Created a chunk of size 800, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 543, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 752, which is longer than the specified 10
# Created a chunk of size 614, which is longer than the specified 10
# Created a chunk of size 497, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 211, which is longer than the specified 10
# Created a chunk of size 613, which is longer than the specified 10
# Created a chunk of size 589, which is longer than the specified 10
# Created a chunk of size 313, which is longer than the specified 10
# Created a chunk of size 288, which is longer than the specified 10
# Created a chunk of size 363, which is longer than the specified 10
# Created a chunk of size 811, which is longer than the specified 10
# Created a chunk of size 601, which is longer than the specified 10
# Created a chunk of size 278, which is longer than the specified 10
# Created a chunk of size 1552, which is longer than the specified 10
# Created a chunk of size 592, which is longer than the specified 10
# Created a chunk of size 829, which is longer than the specified 10
# Created a chunk of size 666, which is longer than the specified 10
# Created a chunk of size 879, which is longer than the specified 10
# Created a chunk of size 269, which is longer than the specified 10
# Created a chunk of size 736, which is longer than the specified 10
# Created a chunk of size 431, which is longer than the specified 10
# Created a chunk of size 725, which is longer than the specified 10
# Created a chunk of size 509, which is longer than the specified 10
# Created a chunk of size 290, which is longer than the specified 10
# Created a chunk of size 424, which is longer than the specified 10
# Created a chunk of size 387, which is longer than the specified 10
# Created a chunk of size 925, which is longer than the specified 10
# Created a chunk of size 330, which is longer than the specified 10
# Created a chunk of size 549, which is longer than the specified 10
# Created a chunk of size 351, which is longer than the specified 10
# Created a chunk of size 305, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 184, which is longer than the specified 10
# Created a chunk of size 339, which is longer than the specified 10
# Created a chunk of size 224, which is longer than the specified 10
# Created a chunk of size 1654, which is longer than the specified 10
# Created a chunk of size 875, which is longer than the specified 10
# Created a chunk of size 1497, which is longer than the specified 10
# Created a chunk of size 364, which is longer than the specified 10
# Created a chunk of size 476, which is longer than the specified 10
# Created a chunk of size 738, which is longer than the specified 10
# Created a chunk of size 529, which is longer than the specified 10
# Created a chunk of size 614, which is longer than the specified 10
# Created a chunk of size 801, which is longer than the specified 10
# Created a chunk of size 230, which is longer than the specified 10
# Created a chunk of size 438, which is longer than the specified 10
# Created a chunk of size 540, which is longer than the specified 10
# Created a chunk of size 219, which is longer than the specified 10
# Created a chunk of size 547, which is longer than the specified 10
# Created a chunk of size 331, which is longer than the specified 10
# Created a chunk of size 461, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 315, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 174, which is longer than the specified 10
# Created a chunk of size 241, which is longer than the specified 10
# Created a chunk of size 475, which is longer than the specified 10
# Created a chunk of size 206, which is longer than the specified 10
# Created a chunk of size 723, which is longer than the specified 10
# Created a chunk of size 249, which is longer than the specified 10
# Created a chunk of size 976, which is longer than the specified 10
# Created a chunk of size 219, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 926, which is longer than the specified 10
# Created a chunk of size 198, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 311, which is longer than the specified 10
# Created a chunk of size 259, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 184, which is longer than the specified 10
# Created a chunk of size 554, which is longer than the specified 10
# Created a chunk of size 674, which is longer than the specified 10
# Created a chunk of size 791, which is longer than the specified 10
# Created a chunk of size 282, which is longer than the specified 10
# Created a chunk of size 230, which is longer than the specified 10
# Created a chunk of size 638, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 344, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 286, which is longer than the specified 10
# Created a chunk of size 418, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 266, which is longer than the specified 10
# Created a chunk of size 615, which is longer than the specified 10
# Created a chunk of size 326, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 993, which is longer than the specified 10
# Created a chunk of size 248, which is longer than the specified 10
# Created a chunk of size 267, which is longer than the specified 10
# Created a chunk of size 450, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 282, which is longer than the specified 10
# Created a chunk of size 250, which is longer than the specified 10
# Created a chunk of size 343, which is longer than the specified 10
# Created a chunk of size 678, which is longer than the specified 10
# Created a chunk of size 249, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 233, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 294, which is longer than the specified 10
# Created a chunk of size 452, which is longer than the specified 10
# Created a chunk of size 583, which is longer than the specified 10
# Created a chunk of size 585, which is longer than the specified 10
# Created a chunk of size 257, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 777, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 263, which is longer than the specified 10
# Created a chunk of size 532, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 304, which is longer than the specified 10
# Created a chunk of size 260, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 245, which is longer than the specified 10
# Created a chunk of size 615, which is longer than the specified 10
# Created a chunk of size 834, which is longer than the specified 10
# Created a chunk of size 278, which is longer than the specified 10
# Created a chunk of size 320, which is longer than the specified 10
# Created a chunk of size 436, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 824, which is longer than the specified 10
# Created a chunk of size 316, which is longer than the specified 10
# Created a chunk of size 239, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 465, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 888, which is longer than the specified 10
# Created a chunk of size 1279, which is longer than the specified 10
# Created a chunk of size 365, which is longer than the specified 10
# Created a chunk of size 223, which is longer than the specified 10
# Created a chunk of size 668, which is longer than the specified 10
# Created a chunk of size 849, which is longer than the specified 10
# Created a chunk of size 202, which is longer than the specified 10
# Created a chunk of size 1048, which is longer than the specified 10
# Created a chunk of size 672, which is longer than the specified 10
# Created a chunk of size 333, which is longer than the specified 10
# Created a chunk of size 465, which is longer than the specified 10
# Created a chunk of size 226, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 556, which is longer than the specified 10
# Created a chunk of size 916, which is longer than the specified 10
# Created a chunk of size 757, which is longer than the specified 10
# Created a chunk of size 759, which is longer than the specified 10
# Created a chunk of size 947, which is longer than the specified 10
# Created a chunk of size 907, which is longer than the specified 10
# Created a chunk of size 849, which is longer than the specified 10
# Created a chunk of size 867, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 804, which is longer than the specified 10
# Created a chunk of size 839, which is longer than the specified 10
# Created a chunk of size 756, which is longer than the specified 10
# Created a chunk of size 866, which is longer than the specified 10
# Created a chunk of size 801, which is longer than the specified 10
# Created a chunk of size 680, which is longer than the specified 10
# Created a chunk of size 171, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 513, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 362, which is longer than the specified 10
# Created a chunk of size 544, which is longer than the specified 10
# Created a chunk of size 818, which is longer than the specified 10
# Created a chunk of size 745, which is longer than the specified 10
# Created a chunk of size 674, which is longer than the specified 10
# Created a chunk of size 672, which is longer than the specified 10
# Created a chunk of size 478, which is longer than the specified 10
# Created a chunk of size 992, which is longer than the specified 10
# Created a chunk of size 769, which is longer than the specified 10
# Created a chunk of size 408, which is longer than the specified 10
# Created a chunk of size 996, which is longer than the specified 10
# Created a chunk of size 233, which is longer than the specified 10
# Created a chunk of size 574, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 274, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 239, which is longer than the specified 10
# Created a chunk of size 474, which is longer than the specified 10
# Created a chunk of size 639, which is longer than the specified 10
# Created a chunk of size 609, which is longer than the specified 10
# Created a chunk of size 268, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 208, which is longer than the specified 10
# Created a chunk of size 1668, which is longer than the specified 10
# Created a chunk of size 376, which is longer than the specified 10
# Created a chunk of size 1618, which is longer than the specified 10
# Created a chunk of size 780, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 155, which is longer than the specified 10
# Created a chunk of size 576, which is longer than the specified 10
# Created a chunk of size 671, which is longer than the specified 10
# Created a chunk of size 816, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 213, which is longer than the specified 10
# Created a chunk of size 167, which is longer than the specified 10
# ...
# Created a chunk of size 371, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 327, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 248, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 368, which is longer than the specified 10
# Created a chunk of size 353, which is longer than the specified 10
# Created a chunk of size 327, which is longer than the specified 10
# Created a chunk of size 357, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 288, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 339, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 316, which is longer than the specified 10
# Created a chunk of size 202, which is longer than the specified 10
# Created a chunk of size 239, which is longer than the specified 10
# Created a chunk of size 1564, which is longer than the specified 10
# Created a chunk of size 244, which is longer than the specified 10
# Created a chunk of size 360, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 307, which is longer than the specified 10
# Created a chunk of size 253, which is longer than the specified 10
# Created a chunk of size 1151, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 663, which is longer than the specified 10
# Created a chunk of size 1214, which is longer than the specified 10
# Created a chunk of size 1215, which is longer than the specified 10
# Created a chunk of size 1068, which is longer than the specified 10
# Created a chunk of size 715, which is longer than the specified 10
# Created a chunk of size 382, which is longer than the specified 10
# Created a chunk of size 1083, which is longer than the specified 10
# Created a chunk of size 752, which is longer than the specified 10
# Created a chunk of size 217, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 548, which is longer than the specified 10
# Created a chunk of size 304, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 859, which is longer than the specified 10
# Created a chunk of size 315, which is longer than the specified 10
# Created a chunk of size 347, which is longer than the specified 10
# Created a chunk of size 480, which is longer than the specified 10
# Created a chunk of size 271, which is longer than the specified 10
# Created a chunk of size 205, which is longer than the specified 10
# Created a chunk of size 312, which is longer than the specified 10
# Created a chunk of size 1042, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 711, which is longer than the specified 10
# Created a chunk of size 256, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 489, which is longer than the specified 10
# Created a chunk of size 556, which is longer than the specified 10
# Created a chunk of size 1255, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 440, which is longer than the specified 10
# Created a chunk of size 694, which is longer than the specified 10
# Created a chunk of size 419, which is longer than the specified 10
# Created a chunk of size 557, which is longer than the specified 10
# Created a chunk of size 444, which is longer than the specified 10
# Created a chunk of size 1175, which is longer than the specified 10
# Created a chunk of size 423, which is longer than the specified 10
# Created a chunk of size 476, which is longer than the specified 10
# Created a chunk of size 768, which is longer than the specified 10
# Created a chunk of size 844, which is longer than the specified 10
# Created a chunk of size 296, which is longer than the specified 10
# Created a chunk of size 307, which is longer than the specified 10
# Created a chunk of size 493, which is longer than the specified 10
# Created a chunk of size 587, which is longer than the specified 10
# Created a chunk of size 668, which is longer than the specified 10
# Created a chunk of size 877, which is longer than the specified 10
# Created a chunk of size 701, which is longer than the specified 10
# Created a chunk of size 652, which is longer than the specified 10
# Created a chunk of size 676, which is longer than the specified 10
# Created a chunk of size 480, which is longer than the specified 10
# Created a chunk of size 521, which is longer than the specified 10
# Created a chunk of size 630, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 607, which is longer than the specified 10
# Created a chunk of size 596, which is longer than the specified 10
# Created a chunk of size 448, which is longer than the specified 10
# Created a chunk of size 288, which is longer than the specified 10
# Created a chunk of size 281, which is longer than the specified 10
# Created a chunk of size 600, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 1077, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 183, which is longer than the specified 10
# Created a chunk of size 188, which is longer than the specified 10
# Created a chunk of size 183, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 217, which is longer than the specified 10
# Created a chunk of size 175, which is longer than the specified 10
# Created a chunk of size 182, which is longer than the specified 10
# Created a chunk of size 156, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 220, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 608, which is longer than the specified 10
# Created a chunk of size 1265, which is longer than the specified 10
# Created a chunk of size 394, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 218, which is longer than the specified 10
# Created a chunk of size 330, which is longer than the specified 10
# Created a chunk of size 1622, which is longer than the specified 10
# Created a chunk of size 177, which is longer than the specified 10
# Created a chunk of size 708, which is longer than the specified 10
# Created a chunk of size 281, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 709, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 627, which is longer than the specified 10
# Created a chunk of size 994, which is longer than the specified 10
# Created a chunk of size 840, which is longer than the specified 10
# Created a chunk of size 797, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 453, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 1061, which is longer than the specified 10
# Created a chunk of size 1581, which is longer than the specified 10
# Created a chunk of size 331, which is longer than the specified 10
# Created a chunk of size 190, which is longer than the specified 10
# Created a chunk of size 202, which is longer than the specified 10
# Created a chunk of size 637, which is longer than the specified 10
# Created a chunk of size 233, which is longer than the specified 10
# Created a chunk of size 664, which is longer than the specified 10
# Created a chunk of size 764, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 341, which is longer than the specified 10
# Created a chunk of size 232, which is longer than the specified 10
# Created a chunk of size 672, which is longer than the specified 10
# Created a chunk of size 220, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 153, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 372, which is longer than the specified 10
# Created a chunk of size 253, which is longer than the specified 10
# Created a chunk of size 301, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 258, which is longer than the specified 10
# Created a chunk of size 258, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 390, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 256, which is longer than the specified 10
# Created a chunk of size 1041, which is longer than the specified 10
# Created a chunk of size 397, which is longer than the specified 10
# Created a chunk of size 480, which is longer than the specified 10
# Created a chunk of size 250, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 288, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 386, which is longer than the specified 10
# Created a chunk of size 269, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 319, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 694, which is longer than the specified 10
# Created a chunk of size 267, which is longer than the specified 10
# Created a chunk of size 829, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 394, which is longer than the specified 10
# Created a chunk of size 643, which is longer than the specified 10
# Created a chunk of size 1047, which is longer than the specified 10
# Created a chunk of size 709, which is longer than the specified 10
# Created a chunk of size 336, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 391, which is longer than the specified 10
# Created a chunk of size 372, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 320, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 1452, which is longer than the specified 10
# Created a chunk of size 343, which is longer than the specified 10
# Created a chunk of size 314, which is longer than the specified 10
# Created a chunk of size 497, which is longer than the specified 10
# Created a chunk of size 236, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 1445, which is longer than the specified 10
# Created a chunk of size 1285, which is longer than the specified 10
# Created a chunk of size 943, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 226, which is longer than the specified 10
# Created a chunk of size 686, which is longer than the specified 10
# Created a chunk of size 802, which is longer than the specified 10
# Created a chunk of size 205, which is longer than the specified 10
# Created a chunk of size 280, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 859, which is longer than the specified 10
# Created a chunk of size 518, which is longer than the specified 10
# Created a chunk of size 240, which is longer than the specified 10
# Created a chunk of size 181, which is longer than the specified 10
# Created a chunk of size 333, which is longer than the specified 10
# Created a chunk of size 232, which is longer than the specified 10
# Created a chunk of size 166, which is longer than the specified 10
# Created a chunk of size 202, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 477, which is longer than the specified 10
# Created a chunk of size 1084, which is longer than the specified 10
# Created a chunk of size 312, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 420, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 210, which is longer than the specified 10
# Created a chunk of size 1008, which is longer than the specified 10
# Created a chunk of size 1311, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 888, which is longer than the specified 10
# Created a chunk of size 811, which is longer than the specified 10
# Created a chunk of size 1128, which is longer than the specified 10
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='"9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike."')

# %%
huggingface_embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

db_books = Chroma.from_documents(
    documents,
    embedding=huggingface_embedding)

# %%
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='6f9ed73d-b7a5-49fb-b8d7-e61ec751e1a1', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience."'),
#  Document(id='1eaca991-5460-4ce0-984c-4ce8147363a2', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808380 Introduce your babies to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing the baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='4d255cd5-08a0-4a93-a773-a69712ffde4b', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808397 Introduce your baby to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to exopse little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information about the subjects."'),
#  Document(id='d3d7ffea-5c7b-4537-9496-5b74ed963aa2', metadata={'source': 'tagged_description.txt'}, page_content='"9780786808373 Introducing your baby to birds, cats, dogs, and babies through fine art, illsutration and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child\'s drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information on the subjects."'),
#  Document(id='7e552dff-7cfc-47ca-9646-e0317d942b44', metadata={'source': 'tagged_description.txt'}, page_content='"9780060959036 Barbara Kingsolver\'s fifth novel is a hymn to wildness that celebrates the prodigal spirit of human nature, and of nature itself. It weaves together three stories of human love within a larger tapestry of lives amid the mountains and farms of southern Appalachia. Over the course of one humid summer, this novel\'s intriguing protagonists face disparate predicaments but find connections to one another and to the flora and fauna with which they necessarily share a place."'),
#  Document(id='01bd49a7-67c6-4a40-b069-3a5d882afc03', metadata={'source': 'tagged_description.txt'}, page_content='"9780786819119 Charming illustrations and playful rhythmic verse make real-life learning fun by taking babies and toddlers on an adventurous discovery of water and its many sources. Squeezable and floatable, Water, Water, Everywhere can be enjoyed in and out of the tub."'),
#  Document(id='d3589743-8e59-477a-9299-912ee2b2b4d8', metadata={'source': 'tagged_description.txt'}, page_content='"9780374522599 The Control of Nature is John McPhee\'s bestselling account of places where people are locked in combat with nature. Taking us deep into these contested territories, McPhee details the strageties and tactics through which people attempt to control nature. Most striking is his depiction of the main contestants: nature in complex and awesome guises, and those attempting to wrest control from her - stubborn, sometimes foolhardy, more often ingenious, and always arresting characters."'),
#  Document(id='13b1f4ab-42d6-4cf5-84ed-9204a100f2dc', metadata={'source': 'tagged_description.txt'}, page_content='"9780064402453 ‘Racso, a brash and boastful little rodent, is making his way to Thorn Valley, determined to learn how to read and write and become a hero. His bragging and lies get him off to a bad start, but a crisis gives him the opportunity to prove his mettle. A worthy successor [to Mrs. Frisby and the Rats of NIMH, a Newbery Medal winner by the author\'s father].\' \'BL. 1986 Children\'s Editors\' Choices (BL) Children\'s Choices for 1987 (IRA/CBC) Notable 1986 Childrens\' Trade Books in Social Studies (NCSS/CBC) 1986 Children\'s Books (NY Public Library) Best Science Fiction/Fantasy 1986 (VOYA)"'),
#  Document(id='8aa712ac-e0fc-464f-898c-4707e3b989aa', metadata={'source': 'tagged_description.txt'}, page_content='"9780064403870 When Margaret and her younger brother, Artie, get lost in the woods on a family camping trip, they are rescued by rats -- the superintelligent rats of NIMH. Taken into the rat\'s community, the children are safe for the time being. But winter is coming. Margaret and Artie have to get back home. And when they do, they must protect the rats who have helped them. Everything depends on their silence... but it\'s hard to evade questions forever. Children\'s Choices for 1991 (IRA/CBC)VOYA\'s Best Science Fiction, Fantasy, and Horror 1990Parenting Honorable Mention, Reading Magic Award"'),
#  Document(id='f2c67343-6f3c-468d-b6d0-5069151e6281', metadata={'source': 'tagged_description.txt'}, page_content='"9780802431486 Drawn from years of counseling and the author\'s own parenting experiences, this valuable resource, filled with Scripture passages and accompanying practical applications, provides principles for raising and nurturing children in these uncertain and rapidly changing times. Original."')]
